# %%
#Run to initialize code
from IPython.display import Markdown, display
import json

from controller import ComplianceController

ctrl = ComplianceController()

# %% [markdown]
# Select Product (Run once, if you wish to grade marketing material for a new product pleace refresh the notebook)

# %%
# Select product - as you add more products it would be better to start using IDs but we are using names for ease of reading here.
product=None
while product is None:
    product_num=input("Enter 1 for Clareon® Toric Intraocular Lens (IOL) or 2 for PRECISION7® Contact Lenses: ")

    if product_num=="1":
        product="ClareonPanOptix"

    elif product_num=="2":
        product="TOTAL30"
    else:
        print("Invalid input, please enter 1 or 2.")
    
    print("Selected product: ", product)

# Load product configuration
ctrl.load_product_policies(product)
# Out:
# Selected product:  TOTAL30

# %%
print("✨ Chatbot ready! Type **exit** to stop.")
print("Use `/grade <text>` to run a new compliance check.")

while True:
    message = input("You: ")

    # Exit command
    if message.lower() in ["exit", "quit", "bye"]:
        display(Markdown("> **Chat ended.**"))
        break

    # Run new compliance check
    if message.startswith("/grade "):
        new_text = message[len("/grade "):].strip()

        if not new_text:
            display(Markdown("🟦 **Bot:** Please provide text after `/grade`."))
            continue
        
        compliance_grade = ctrl.run_compliance_check(new_text)

        display(Markdown(
            f"""
🟦 **You:** {new_text}

🟩 **Compliance Updated!**  
{json.dumps(compliance_grade, indent=2)}
            """
        ))
        continue


    # ---------------------------
    #  Normal chat
    # ---------------------------
    response = ctrl.chat_bot_message(message)

    display(Markdown(
        f"""
🟦 **You:** {message}

⬜ **Bot:**  
{response}
        """
    ))
# Out:
# ✨ Chatbot ready! Type **exit** to stop.
# Use `/grade <text>` to run a new compliance check.
# 🟦 **You:** test just give me stuff
#
# 🟩 **Compliance Updated!**
# {
#   "scores": {
#     "approved": 0,
#     "fda": 90.0,
#     "ftc": 90.0
#   },
#   "filtered_evaluations": [],
#   "approved_matches": [],
#   "approved_match_summary": "No matching approved claims.",
#   "overall_summary": "Marketing text shows no similarity to approved claims and poses no FDA or FTC compliance conflicts."
# }
# 🟦 **You:** test chat
#
# ⬜ **Bot:**
# Your last marketing text for TOTAL30 has no matches to approved claims but shows no FDA or FTC compliance issues. Let me know if you want suggestions to improve claim alignment or compliance!
# 🟦 **You:**
#
# ⬜ **Bot:**
# Let me know if you have new marketing text for TOTAL30 to review or if you want recommendations to improve compliance and claim alignment!
