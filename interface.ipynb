# %%
#Run to initialize code
from IPython.display import Markdown, display
import json

from controller import ComplianceController

ctrl = ComplianceController()

# %% [markdown]
# Select Product (Run once, if you wish to grade marketing material for a new product pleace refresh the notebook)

# %%
# Select product - as you add more products it would be better to start using IDs but we are using names for ease of reading here.
product=None
while product is None:
    product_num=input("Enter 1 for Clareon® Toric Intraocular Lens (IOL) or 2 for PRECISION7® Contact Lenses: ")

    if product_num=="1":
        product="ClareonPanOptix"

    elif product_num=="2":
        product="TOTAL30"
    else:
        print("Invalid input, please enter 1 or 2.")
    
    print("Selected product: ", product)
# Out:
# Selected product:  TOTAL30

# %%
print("✨ Chatbot ready! Type **exit** to stop.")
print("Use `/grade <text>` to run a new compliance check.")
print("Use `/summary` to see the current compliance grade.\n")

while True:
    message = input("You: ")

    # Exit command
    if message.lower() in ["exit", "quit", "bye"]:
        display(Markdown("> **Chat ended.**"))
        break

    # Run new compliance check
    if message.startswith("/grade "):
        new_text = message[len("/grade "):].strip()

        if not new_text:
            display(Markdown("🟦 **Bot:** Please provide text after `/grade`."))
            continue
        
        compliance_grade = ctrl.run_compliance_check(new_text, product)

        display(Markdown(
            f"""
🟦 **You:** {new_text}

🟩 **Compliance Updated!**  
{json.dumps(compliance_grade, indent=2)}
            """
        ))
        continue

    # ---------------------------
    #  /summary
    # ---------------------------
    if message.strip() == "/summary":
        if ctrl.compliance_grade:
            display(Markdown(
                f"""
🟦 **You:** /summary  

📊 **Current Compliance Grade:**  
{json.dumps(ctrl.compliance_grade, indent=2)}
                """
            ))
        else:
            display(Markdown("🟦 **Bot:** No compliance grade available yet."))
        continue

    # ---------------------------
    #  Normal chat
    # ---------------------------
    response = ctrl.chat_bot_message(message)

    display(Markdown(
        f"""
🟦 **You:** {message}

⬜ **Bot:**  
{response}
        """
    ))
# Out:
# ✨ Chatbot ready! Type **exit** to stop.
# Use `/grade <text>` to run a new compliance check.
# Use `/summary` to see the current compliance grade.
# 🟦 **You:** good for eyes
#
# 🟩 **Compliance Updated!**
# {
#   "scores": {
#     "approved": 30,
#     "fda": 84.16666666666666,
#     "ftc": 88.5
#   },
#   "filtered_evaluations": [
#     {
#       "policy_id": "fda:9",
#       "policy": "21 CFR \u00a7 801.109(c)-(d): Prescription devices\u2014labeling in or on the dispensing package shall bear information for use, including indications, hazards, contraindications, side effects, and precautions; any distributed labeling must contain adequate information for such use.",
#       "type": "fda",
#       "grade": 60,
#       "reason": "Minor risk: \"Good for eyes\" implies a health benefit without adequate risk or usage information."
#     },
#     {
#       "policy_id": "ftc:24",
# ...

# %% [markdown]
# Input Marketing Material (Run again whenever you want to make changes to your marketing material)

# %%
#Update or create marketing material
marketing_text = input("Enter marketing material: ")
compliance_grade = ctrl.run_compliance_check(marketing_text, product)

print(compliance_grade)

# %% [markdown]
# Start chatting to Chatbot

# %%
print("Chatbot ready! Type 'exit' to stop.")
print("Use `/grade <text>` to run a new compliance check.\n")

while True:
    message = input("You: ")

    # Exit command
    if message.lower() in ["exit", "quit", "bye"]:
        print("Chat ended.")
        break

    # NEW FEATURE: run compliance during chat
    if message.startswith("/grade "):
        new_text = message[len("/grade "):].strip()

        if not new_text:
            print("Bot: Please provide marketing material after /grade.\n")
            continue

        compliance_grade = ctrl.run_compliance_check(new_text, product)
        print("\nBot: Compliance updated!")
        print(compliance_grade)
        print()
        continue

    # Normal chatbot interaction
    response = ctrl.chat_bot_message(message)
    print("\nBot:", response, "\n")
